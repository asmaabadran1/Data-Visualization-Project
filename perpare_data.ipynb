# %%
import pandas as  pd

# %%
cat=pd.read_excel("/content/sample_data/catex.xlsx")

# %%
cat
# Out:
#                     Breed                                  Temperament  \
# 0          Abyssinian Cat        Playful, willful, active, intelligent
# 1              Aegean Cat   Affectionate, social, playful, intelligent
# 2    American Bobtail Cat     Lively, intelligent, personable, curious
# 3       American Curl Cat        Curious, intelligent, social, playful
# 4   American Longhair Cat    Sociable, easygoing, playful, inquisitive
# ..                    ...                                          ...
# 75        Turkish Van Cat    Active, affectionate, personable, playful
# 76  Turkish Vankedisi Cat      Active, affectionate, pleasant, playful
# 77   Ukrainian Levkoy Cat     Playful, affectionate, curious, sociable
# 78             Ussuri Cat  Athletic, playful, independent, intelligent
# 79     York Chocolate Cat        Friendly, athletic, devoted, charming
#
#                   Origin                                         Group  \
# ...

# %%
unique_values = cat['Origin'].unique()
print(unique_values)
# Out:
# ['Abyssinia (Ethiopia)' 'Greece' 'United States' 'United Kingdom'
#  'Australia' 'Burma' 'Brazil' 'Burma / Myanmar' 'France, Syria'
#  'Egypt, South Asia' 'Isle of Man' 'Russia' 'China' 'Egypt' 'Sweden'
#  'Germany' 'Japan' 'Canada' 'Thailand' 'Norway'
#  'United States, United Kingdom' 'Iran' 'United States, Africa'
#  'Singapore' 'Kenya' 'Turkey' 'Ukraine']

# %%
origin_to_continent = {'Abyssinia (Ethiopia)': 'Africa',
                       'Iran': 'Asia',
                       'Turkey': 'Asia and Europe',
                       'United Kingdom': 'Europe',
                       'United States': 'North America',
                       'Norway': 'Europe',
                       'Burma': 'Asia',
                       'Australia': 'Australia/Oceania',
                       'Greece': 'Europe',
                       'Russia': 'Europe and Asia',
                       'Brazil': 'South America',
                       'Canada': 'North America',
                       'Thailand': 'Asia',
                       'Egypt, South Asia': 'Africa and Asia',
                       'France, Syria': 'Europe and Asia',
                       'United States, United Kingdom': 'North America and Europe',
                       'Singapore': 'Asia',
                       'Japan': 'Asia',
                       'Isle of Man': 'Europe',
                       'Burma / Myanmar': 'Asia',
                       'Germany': 'Europe',
                       'United States, Africa': 'North America and Africa',
                       'Sweden': 'Europe',
                       'Egypt': 'Africa',
                       'Ukraine': 'Europe',
                       'China': 'Asia',
                       'Kenya': 'Africa'}


cat['Continents'] = cat['Origin'].replace(origin_to_continent)

# %%
cat
# Out:
#                     Breed                                  Temperament  \
# 0          Abyssinian Cat        Playful, willful, active, intelligent
# 1              Aegean Cat   Affectionate, social, playful, intelligent
# 2    American Bobtail Cat     Lively, intelligent, personable, curious
# 3       American Curl Cat        Curious, intelligent, social, playful
# 4   American Longhair Cat    Sociable, easygoing, playful, inquisitive
# ..                    ...                                          ...
# 75        Turkish Van Cat    Active, affectionate, personable, playful
# 76  Turkish Vankedisi Cat      Active, affectionate, pleasant, playful
# 77   Ukrainian Levkoy Cat     Playful, affectionate, curious, sociable
# 78             Ussuri Cat  Athletic, playful, independent, intelligent
# 79     York Chocolate Cat        Friendly, athletic, devoted, charming
#
#                   Origin                                         Group  \
# ...

# %%
cat['Height']
# Out:
# 0      8"-10"
# 1      8"-10"
# 2     10"-14"
# 3      8"-10"
# 4     10"-14"
#        ...
# 75    9"- 11"
# 76    9"- 11"
# 77    8"- 10"
# 78    9"- 11"
# 79     8"-10"
# Name: Height, Length: 80, dtype: object

# %%
cat['Height'] = cat['Height'].str.replace('"',' ' )

# %%
cat['Height']
# Out:
# 0      8 -10
# 1      8 -10
# 2     10 -14
# 3      8 -10
# 4     10 -14
#        ...
# 75    9 - 11
# 76    9 - 11
# 77    8 - 10
# 78    9 - 11
# 79     8 -10
# Name: Height, Length: 80, dtype: object

# %%
cat['min_Height']  = cat['Height'] .apply(lambda x: x.split('-')[0])
cat['max_Height']  = cat['Height'] .apply(lambda x: x.split('-')[1])

# %%
unique_values = cat['min_Height'].unique()
print(unique_values)
# Out:
# ['8 ' '10 ' '14 ' '11 ' '12 ' '7”' '6 ' '9 ' '7 ' '21 ']

# %%
unique_values = cat['max_Height'].unique()
print(unique_values)
# Out:
# ['10 ' '14 ' '18 ' '11 ' '12 ' '16 ' '8”' '9 ' ' 13 ' ' 10 ' ' 14 ' ' 11 '
#  ' 8 ' ' 23 ']

# %%
cat['max_Height'] = cat['max_Height'].str.replace('”',' ' )
cat['min_Height'] = cat['min_Height'].str.replace('”',' ' )

# %%
unique_values = cat['max_Height'].unique()
print(unique_values)
# Out:
# ['10 ' '14 ' '18 ' '11 ' '12 ' '16 ' '8 ' '9 ' ' 13 ' ' 10 ' ' 14 ' ' 11 '
#  ' 8 ' ' 23 ']

# %%
unique_values = cat['min_Height'].unique()
print(unique_values)
# Out:
# ['8 ' '10 ' '14 ' '11 ' '12 ' '7 ' '6 ' '9 ' '21 ']

# %%
cat['Body Length'] = cat['Body Length'].str.replace('"',' ' )
cat['min_Body Length']  = cat['Body Length'] .apply(lambda x: x.split('-')[0])
cat['max_Body Length']  = cat['Body Length'] .apply(lambda x: x.split('-')[1])

# %%
cat['max_Body Length']
# Out:
# 0     16
# 1     16
# 2     20
# 3     16
# 4     17
#      ...
# 75    17
# 76    17
# 77    16
# 78    16
# 79    15
# Name: max_Body Length, Length: 80, dtype: object

# %%
unique_values = cat['min_Body Length'].unique()
print(unique_values)
# Out:
# ['12 ' '16 ' '15 ' '11 ' '13 ' '14 ' '10 ' '17 ' '20 ' '9 ']

# %%
unique_values = cat['max_Body Length'].unique()
print(unique_values)
# Out:
# ['16 ' '20 ' '17 ' '22 ' '18 ' '14 ' '24 ' '12 ' '21 ' '15 ']

# %%
cat['Weight'] = cat['Weight'].str.replace('"', '')

# %%
cat['Weight']
# Out:
# 0      8-12
# 1      7-10
# 2      7-18
# 3      5-10
# 4     8-15
#       ...
# 75     7-20
# 76     7-19
# 77    11-15
# 78    11-15
# 79    10-16
# Name: Weight, Length: 80, dtype: object

# %%
cat['min_Weight']  = cat['Weight'] .apply(lambda x: x.split('-')[0])
cat['max_Weight']  = cat['Weight'] .apply(lambda x: x.split('-')[1])

# %%
unique_values = cat['min_Weight'].unique()
print(unique_values)
unique_values = cat['max_Weight'].unique()
print(unique_values)
# Out:
# ['8' '7' '5' '4' '12' '6' '10' '9' '11' '6 ' '15' '17']
# ['12' '10' '18' '15 ' '15' '14' '22' '11' '25' '9' '6' '20' '13' '8' '16'
#  '20 ' '28' '26' '19']

# %%
cat['Life Expectancy'] = cat['Life Expectancy'].str.replace('"', '')

# %%
cat['min_Life Expectancy']  = cat['Life Expectancy'] .apply(lambda x: x.split('-')[0])
cat['max_Life Expectancy']  = cat['Life Expectancy'] .apply(lambda x: x.split('-')[1])

# %%
unique_values = cat['min_Life Expectancy'].unique()
print(unique_values)
unique_values = cat['max_Life Expectancy'].unique()
print(unique_values)
# Out:
# ['9' '12' '11' '14' '12 ' '10' '15' '8 ' '13' '18' '8']
# ['13' '12 ' '15' '17' '16' '17 ' '18' '20' '15 ' '16 ' ' 20' '12' ' 12'
#  '19' '20 ' '14']

# %%
cat['min_Life Expectancy'] = cat['min_Life Expectancy'].astype(int)
cat['max_Life Expectancy'] = cat['max_Life Expectancy'].astype(int)
cat['max_Weight'] = cat['max_Weight'].astype(int)
cat['min_Weight'] = cat['min_Weight'].astype(int)
cat['min_Body Length']  = cat['min_Body Length'] .astype(int)
cat['max_Body Length']  = cat['max_Body Length'] .astype(int)
cat['min_Height']  = cat['min_Height'] .astype(int)
cat['max_Height']  = cat['max_Height'] .astype(int)

# %%
cat['avr_Life Expectancy'] = cat[['min_Life Expectancy', 'max_Life Expectancy']].mean(axis=1)
cat['avr_Weight'] = cat[['max_Weight', 'min_Weight']].mean(axis=1)
cat['avr_Body Length'] = cat[['min_Body Length', 'max_Body Length']].mean(axis=1)
cat['avr_Height'] = cat[['min_Height', 'max_Height']].mean(axis=1)

# %%
#cat["Group"][0].split(" ")[0]

# %%
unique_values = cat['Group'].unique()
print(unique_values)
# Out:
# ['Medium-sized short-haired'
#  'Medium-to-large sized shorthair and longhair'
#  'Small-sized short to medium hair' 'Medium-to-large sized longhair'
#  'Medium to large-sized shorthair and longhair'
#  'Medium-to-large sized shorthair' 'Medium-sized short to medium hair'
#  'Medium to large sized medium to long hair'
#  'Small to medium-sized longhair' 'Large shorthair'
#  'Medium sized longhair' 'Medium-to-large shorthair'
#  'Medium-to-large longhair' 'Medium-sized shorthair and longhair'
#  'Medium-sized semi-longhair' 'Large short-haired'
#  'Small to medium-sized shorthair'
#  'Medium-sized short-haired and long-haired' 'Medium-sized hairless'
#  'Small short-haired' 'Medium-sized longhair' 'Medium-sized long-haired'
#  'Medium to large short-haired and long-haired\n' 'Large Longhair'
#  'Medium, long hair or short hair' 'Small short-haired and long-haired'
#  'Small to medium-sized long-haired' 'Large long-haired'
#  'Medium-to-large short-haired' 'Medium-sized Short-haired'
# ...

# %%
cat
# Out:
#                     Breed                                  Temperament  \
# 0          Abyssinian Cat        Playful, willful, active, intelligent
# 1              Aegean Cat   Affectionate, social, playful, intelligent
# 2    American Bobtail Cat     Lively, intelligent, personable, curious
# 3       American Curl Cat        Curious, intelligent, social, playful
# 4   American Longhair Cat    Sociable, easygoing, playful, inquisitive
# ..                    ...                                          ...
# 75        Turkish Van Cat    Active, affectionate, personable, playful
# 76  Turkish Vankedisi Cat      Active, affectionate, pleasant, playful
# 77   Ukrainian Levkoy Cat     Playful, affectionate, curious, sociable
# 78             Ussuri Cat  Athletic, playful, independent, intelligent
# 79     York Chocolate Cat        Friendly, athletic, devoted, charming
#
#                   Origin                                         Group  \
# ...

# %%
#cat.to_excel('final_cat.xlsx', index=False)

# %%
cat['Group'] = cat['Group'].str.replace('-', ' ')

# %%
'''values_to_split_on =['Mediumsized' ,'Medium',
 'Small to mediumsized' ,'Medium to large',
 'Mediumtolarge', 'Mediumsized' ,'Large',
 'Medium to large sized' ,'Medium sized',
 'Mediumsized ' ,'Small to mediumsized '
 'Mediumtolarge sized', 'Large'
 'Largesized' ,'Mediumtolarge',
 'Mediumsized', 'Medium to large',
 'Medium to largesized',
 'Mediumsized', 'Large',
 'Largesized' ,'Small shorthaired',
 'Mediumsized', 'Mediumsized', 'Large',
 'Small', 'Mediumtolarge sized',
 'Mediumtolarge sized', 'Mediumtolarge',
 'Mediumsized', 'Large',
 'Largesized', 'Small',
 'Mediumsized' ,'Mediumsized', 'Large',
 'Small' ,'Mediumtolarge',
 'Mediumtolarge sized', 'Mediumtolarge',
 'Small to mediumsized', 'Mediumsized',
 'Smallsized',
 'Medium to large',
 'Medium', 'Mediumsized',
 'Small to mediumsized']'''
# Out:
# "values_to_split_on =['Mediumsized' ,'Medium',\n 'Small to mediumsized' ,'Medium to large',\n 'Mediumtolarge', 'Mediumsized' ,'Large',\n 'Medium to large sized' ,'Medium sized',\n 'Mediumsized ' ,'Small to mediumsized '\n 'Mediumtolarge sized', 'Large'\n 'Largesized' ,'Mediumtolarge',\n 'Mediumsized', 'Medium to large',\n 'Medium to largesized',\n 'Mediumsized', 'Large',\n 'Largesized' ,'Small shorthaired',\n 'Mediumsized', 'Mediumsized', 'Large',\n 'Small', 'Mediumtolarge sized',\n 'Mediumtolarge sized', 'Mediumtolarge',\n 'Mediumsized', 'Large',\n 'Largesized', 'Small',\n 'Mediumsized' ,'Mediumsized', 'Large',\n 'Small' ,'Mediumtolarge',\n 'Mediumtolarge sized', 'Mediumtolarge',\n 'Small to mediumsized', 'Mediumsized',\n 'Smallsized',\n 'Medium to large',\n 'Medium', 'Mediumsized',\n 'Small to mediumsized']"

# %%
cat['Group']
# Out:
# 0                        Medium sized short haired
# 1                        Medium sized short haired
# 2     Medium to large sized shorthair and longhair
# 3                 Small sized short to medium hair
# 4                   Medium to large sized longhair
#                           ...
# 75                               Large long haired
# 76                               Large long haired
# 77                           Medium sized hairless
# 78                    Medium to large short haired
# 79                               Large long haired
# Name: Group, Length: 80, dtype: object

# %%
split_col = cat['Group'].str.split(' ', n=1, expand=True)

cat.insert(1, 'Size', split_col[0])

# %%
cat
# Out:
#                     Breed    Size  \
# 0          Abyssinian Cat  Medium
# 1              Aegean Cat  Medium
# 2    American Bobtail Cat  Medium
# 3       American Curl Cat   Small
# 4   American Longhair Cat  Medium
# ..                    ...     ...
# 75        Turkish Van Cat   Large
# 76  Turkish Vankedisi Cat   Large
# 77   Ukrainian Levkoy Cat  Medium
# 78             Ussuri Cat  Medium
# 79     York Chocolate Cat   Large
#
#                                     Temperament                Origin  \
# 0         Playful, willful, active, intelligent  Abyssinia (Ethiopia)
# 1    Affectionate, social, playful, intelligent                Greece
# 2      Lively, intelligent, personable, curious         United States
# 3         Curious, intelligent, social, playful         United States
# 4     Sociable, easygoing, playful, inquisitive         United States
# ..                                          ...                   ...
# ...

# %%
unique_values = cat['Size'].unique()
print(unique_values)
# Out:
# ['Medium' 'Small' 'Large' 'Medium,']

# %%
cat['Group']= cat['Group'].str.rsplit(' ', n=1, expand=True).apply(lambda x: x[0] + x[1], axis=1)

# %%
last_word_col = cat['Group'].str.rsplit(' ', n=1, expand=True)[1]

cat.insert(1, 'Hair', last_word_col)

# %%
unique_values = cat['Hair'].unique()
print(unique_values)
# Out:
# ['shorthaired' 'andlonghair' 'mediumhair' 'sizedlonghair' 'sizedshorthair'
#  'longhair' None 'largeshorthair' 'largelonghair' 'semilonghair'
#  'longhaired' 'sizedhairless' 'longhaired\n' 'shorthair' 'Shorthaired']

# %%
cat['Hair'] = cat['Hair'].str.replace('\n', '')

# %%
cat['Hair'] = cat['Hair'].str.replace('sized', '')

# %%
cat['Hair'] = cat['Hair'].str.replace('and', '')

# %%
cat['Hair']= cat['Hair'].str.replace(r'ed\b', '', regex=True)

# %%
unique_values = cat['Hair'].unique()
print(unique_values)
# Out:
# ['shorthair' 'longhair' 'mediumhair' None 'largeshorthair' 'largelonghair'
#  'semilonghair' 'hairless' 'Shorthair']

# %%
cat['Size'] =cat['Size'].str.replace(',', '')

# %%
unique_values = cat['Size'].unique()
print(unique_values)
# Out:
# ['Medium' 'Small' 'Large']

# %%
cat.to_excel('final_filee.xlsx', index=False)
